# %% [markdown]
# ### PRP
#
# Local directory `millercenter.org` is a simple `wget` mirror. Each page in the `exhibits` directory represents an exhibit.
#
# For each exhibit, if it has a swf/flash embed, we would like to have structured information about each swf/flash file:
#
# * URL
# * HTML page title
# * title
# * date of recording
# * participants
# * convesation number
# * administration

# %%
# Prepare a list of dict as a table to provide as CSV in the end.

exhibit_list = []

# %%
# Get a list of all filepaths of pages.

import glob
import os

basepath = 'millercenter.org/presidentialclassroom/exhibits/'
curdir = os.path.abspath(os.curdir)
filepath_list = sorted(glob.glob(basepath + '*'))

# %%
# Define parser: filepath -> exhibit dict.

from pyquery import PyQuery as pq

def parse_exhibit(filepath, curdir=curdir):
    exhibit = {'url': filepath}
    dom = pq(url='file:///'+curdir+'/'+filepath)
    # TODO: GET TO WORK.
    return exhibit

# %%
# Parse all pages.

for filepath in filepath_list:
    if os.
    exhibit = parse_exhibit(filepath)
    if exhibit is not None:
        exhibit_list.append(exhibit)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /opt/python3.4/lib/python3.4/urllib/request.py in open_local_file(self, req)
#    1337         try:
# -> 1338             stats = os.stat(localfile)
#    1339             size = stats.st_size
#
# FileNotFoundError: [Errno 2] No such file or directory: '//home/rduplain/millercenter/millercenter.org/presidentialclassroom/exhibits/Lessons for 2012—Miller Center_files'
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-27-b4ea745357c7> in <module>()
#       2
#       3 for filepath in filepath_list:
# ----> 4     exhibit = parse_exhibit(filepath)
#       5     if exhibit is not None:
#       6         exhibit_list.append(exhibit)
#
# <ipython-input-26-4c13a2f4ca54> in parse_exhibit(filepath, curdir)
#       5 def parse_exhibit(filepath, curdir=curdir):
#       6     exhibit = {'url': filepath}
# ----> 7     dom = pq(url='file:///'+curdir+'/'+filepath)
#       8     # TODO: GET TO WORK.
#       9     return exhibit
#
# /home/rduplain/.virtualenvs/millercenter/lib/python3.4/site-packages/pyquery/pyquery.py in __init__(self, *args, **kwargs)
#     192                     html = opener(url, **kwargs)
#     193                 else:
# --> 194                     html = url_opener(url, kwargs)
#     195                 if not self.parser:
#     196                     self.parser = 'html'
#
# /home/rduplain/.virtualenvs/millercenter/lib/python3.4/site-packages/pyquery/openers.py in url_opener(url, kwargs)
#      70     if HAS_REQUEST:
#      71         return _requests(url, kwargs)
# ---> 72     return _urllib(url, kwargs)
#
# /home/rduplain/.virtualenvs/millercenter/lib/python3.4/site-packages/pyquery/openers.py in _urllib(url, kwargs)
#      64     method = kwargs.get('method')
#      65     url, data = _query(url, method, kwargs)
# ---> 66     return urlopen(url, data)
#      67
#      68
#
# /opt/python3.4/lib/python3.4/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     159     else:
#     160         opener = _opener
# --> 161     return opener.open(url, data, timeout)
#     162
#     163 def install_opener(opener):
#
# /opt/python3.4/lib/python3.4/urllib/request.py in open(self, fullurl, data, timeout)
#     461             req = meth(req)
#     462
# --> 463         response = self._open(req, data)
#     464
#     465         # post-process response
#
# /opt/python3.4/lib/python3.4/urllib/request.py in _open(self, req, data)
#     479         protocol = req.type
#     480         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 481                                   '_open', req)
#     482         if result:
#     483             return result
#
# /opt/python3.4/lib/python3.4/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     439         for handler in handlers:
#     440             func = getattr(handler, meth_name)
# --> 441             result = func(*args)
#     442             if result is not None:
#     443                 return result
#
# /opt/python3.4/lib/python3.4/urllib/request.py in file_open(self, req)
#    1314                 raise URLError("file:// scheme is supported only on localhost")
#    1315         else:
# -> 1316             return self.open_local_file(req)
#    1317
#    1318     # names for the localhost
#
# /opt/python3.4/lib/python3.4/urllib/request.py in open_local_file(self, req)
#    1354         except OSError as exp:
#    1355             # users shouldn't expect OSErrors coming from urlopen()
# -> 1356             raise URLError(exp)
#    1357         raise URLError('file not on local host')
#    1358
#
# URLError: <urlopen error [Errno 2] No such file or directory: '//home/rduplain/millercenter/millercenter.org/presidentialclassroom/exhibits/Lessons for 2012—Miller Center_files'>

# %%
# Write table to CSV.

import csv
import sys

fieldnames = (
    'url',
    'page_title',
    'title',
    'date_of_recording',
    'participant1',
    'participant2',
    'participant3',
    'participant4',
    'participant5',
    'participant6',
    'participant7',
    'participant8',
    'conversation_number',
    'administration',
)

def write_csv(exhibit_list, fd, fieldnames=fieldnames):
    writer = csv.DictWriter(fd, fieldnames=fieldnames)
    writer.writeheader()
    for exhibit in exhibit_list:
        writer.writerow(exhibit)

write_csv(exhibit_list, open('exhibits-with-swf.csv', 'w'))

# %%
import pandas as pd

pd.read_csv('exhibits-with-swf.csv')
# Out:
#      url  page_title  title  date_of_recording  participant1  participant2  \
# 0    NaN         NaN    NaN                NaN           NaN           NaN
# 1    NaN         NaN    NaN                NaN           NaN           NaN
# 2    NaN         NaN    NaN                NaN           NaN           NaN
# 3    NaN         NaN    NaN                NaN           NaN           NaN
# 4    NaN         NaN    NaN                NaN           NaN           NaN
# 5    NaN         NaN    NaN                NaN           NaN           NaN
# 6    NaN         NaN    NaN                NaN           NaN           NaN
# 7    NaN         NaN    NaN                NaN           NaN           NaN
# 8    NaN         NaN    NaN                NaN           NaN           NaN
# 9    NaN         NaN    NaN                NaN           NaN           NaN
# 10   NaN         NaN    NaN                NaN           NaN           NaN
# 11   NaN         NaN    NaN                NaN           NaN           NaN
# 12   NaN         NaN    NaN                NaN           NaN           NaN
# 13   NaN         NaN    NaN                NaN           NaN           NaN
# 14   NaN         NaN    NaN                NaN           NaN           NaN
# 15   NaN         NaN    NaN                NaN           NaN           NaN
# 16   NaN         NaN    NaN                NaN           NaN           NaN
# 17   NaN         NaN    NaN                NaN           NaN           NaN
# 18   NaN         NaN    NaN                NaN           NaN           NaN
# 19   NaN         NaN    NaN                NaN           NaN           NaN
# 20   NaN         NaN    NaN                NaN           NaN           NaN
# 21   NaN         NaN    NaN                NaN           NaN           NaN
# 22   NaN         NaN    NaN                NaN           NaN           NaN
# 23   NaN         NaN    NaN                NaN           NaN           NaN
# 24   NaN         NaN    NaN                NaN           NaN           NaN
# 25   NaN         NaN    NaN                NaN           NaN           NaN
# 26   NaN         NaN    NaN                NaN           NaN           NaN
# 27   NaN         NaN    NaN                NaN           NaN           NaN
# 28   NaN         NaN    NaN                NaN           NaN           NaN
# 29   NaN         NaN    NaN                NaN           NaN           NaN
# ..   ...         ...    ...                ...           ...           ...
# 208  NaN         NaN    NaN                NaN           NaN           NaN
# 209  NaN         NaN    NaN                NaN           NaN           NaN
