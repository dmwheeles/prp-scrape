# %% [markdown]
# ### PRP
#
# Local directory `millercenter.org` is a simple `wget` mirror. Each page in the `exhibits` directory represents an exhibit.
#
# For each exhibit, if it has a swf/flash embed, we would like to have structured information about each swf/flash file:
#
# * URL
# * HTML page title
# * title
# * date of recording
# * participants
# * convesation number
# * administration

# %%
# Prepare a logger.

import logging

logger = logging.getLogger()
logger.handlers = []
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.DEBUG)

# %%
# Prepare a file for context information.

log = open('millercenter.log', 'w')

# %%
# Prepare a list of dict as a table to provide as CSV in the end.

exhibit_list = []

# %%
# Get a list of all filepaths of pages.

import glob
import os

basepath = 'millercenter.org/presidentialclassroom/exhibits/'
curdir = os.path.abspath(os.curdir)
filepath_list = sorted(glob.glob(basepath + '*'))

# %%
# Define parser: filepath -> exhibit dict.

import os

from pyquery import PyQuery as pq

def parse_exhibit(filepath, curdir=curdir, logger=logger, log=log):
    exhibit = {'url': filepath}
    dom = pq(url='file:///'+curdir+'/'+filepath)

    if not dom('article iframe'):
        msg = 'no iframe found: {}'.format(os.path.basename(filepath))
        logger.warning(msg)
        log.write(msg + '\n')
        return

    exhibit['page_title'] = dom('title').text()
    exhibit['title'] = dom('article h1').text()

    try:
        date, participants, conversation_number = parse_struct(dom, logger=logger, log=log)
    except IndexError:
        msg = 'structure unknown: {}'.format(os.path.basename(filepath))
        logger.warning(msg)
        log.write(msg + '\n')
        return
    except AttributeError:
        msg = 'structure inconsistent: {}'.format(os.path.basename(filepath))
        logger.warning(msg)
        log.write(msg + '\n')
        return

    exhibit['date_of_recording'] = date
    exhibit['conversation_number'] = conversation_number
    
    for i, participant in enumerate(participants.split(',')):
        exhibit['participant'+str(i+1)] = participant.strip()

    return exhibit    


def parse_struct(dom, logger=logger, log=log):
    "Return date, participants, conversation_number if feasible, else IndexError."
    
    for p in dom('article p'):
        subdom = pq(p)
        if len(subdom('strong')) >= 3:
            break
    else:
        raise IndexError('while looking for p')

    contents = subdom.contents()
    for i, x in enumerate(contents):
        if hasattr(x, 'tag') and x.tag == 'strong':
            break
    else:
        raise IndexError('while looking for strong')

    contents = contents[i:]
    contents = [x for x in contents if x != '\n\t']

    if dom('article p').text().find('Time') >= 0:
        # Time is contents[4].
        contents = [contents[1], contents[7], contents[10]]
    else:
        contents = [contents[1], contents[4], contents[7]]

    contents = [x.lstrip(':').strip() for x in contents]
    return contents

# %%
# Parse all pages.

for filepath in filepath_list:
    if not os.path.isfile(filepath):
        # Not a regular file, likely a directory.
        continue
    exhibit = parse_exhibit(filepath)
    if exhibit is not None:
        exhibit_list.append(exhibit)
# Out:
# no iframe found: 1963_0108_status
# no iframe found: 1963_0115_dispatching
# no iframe found: 1963_0202_wheelerreport
# no iframe found: 1963_1002_reporting
# no iframe found: 1963_1029_robertkennedy
# no iframe found: 1963_1104_overthrow
# no iframe found: 1965_0707_king
# structure unknown: a-japanese-ultimatum
# no iframe found: a-rough-guide-to-richard-nixons-conspiracy-theories
# no iframe found: administrations
# structure unknown: albert-thomas-gets-the-johnson-treatment
# no iframe found: assassination-dr-martin-luther-king
# structure unknown: beating-mcgovern
# no iframe found: behind-scenes-election-night
# no iframe found: behind-the-scenes-election-night
# no iframe found: cancer-presidency
# structure unknown: civil-rights-act
# no iframe found: civil-rights-lyndon-johnson-voter-intimidation-1964-election
# no iframe found: conspiracy
# no iframe found: delaying-indictments
# no iframe found: destroying-tapes
# no iframe found: destroying-watergate-tapes
# structure unknown: dispatching-the-wheeler-mission
# no iframe found: dr-martin-luther-king-lbj-and-jfk
# no iframe found: edward-r-murrow-lbj
# no iframe found: everybody-bugs-everybody-else
# no iframe found: exceptional-alliance
# no iframe found: executive-privilege
# no iframe found: financing-kennedy-write-campaign
# no iframe found: first-domino-nixon-and-pentagon-papers
# no iframe found: former-virginia-governor-linwood-holton-and-the-nixon-tapes
# no iframe found: get-me-names-jews
# no iframe found: get-me-the-names-of-the-jews
# no iframe found: gi-bill
# no iframe found: going-after-dan-schorr
# no iframe found: gulf-of-tonkin-1964-perspectives
# no iframe found: gulf-tonkin-1964-perspectives
# no iframe found: guy-wholl-get-out-and-tear-things
# no iframe found: hes-just-got-tell-them-lay
# no iframe found: hoover-rugged-individualism
# no iframe found: how-much-money-involved
# no iframe found: howard-hunt
# no iframe found: howard-hunt-2
# no iframe found: i-really-need-son-bitch
# no iframe found: i-want-brookings-institute-safe-cleaned-out
# no iframe found: i-want-goddamn-funds
# no iframe found: if-it-blows-it-blows
# no iframe found: it-just-repels-him-do-these-horrible-things
# structure unknown: its-a-pentagon-study-huh
# no iframe found: its-balls-thing
# structure unknown: jfk-and-harold-macmillan-on-the-cuban-missile-crisis
# structure unknown: jfk-and-taylor-on-the-sino-soviet-split
# structure unknown: jfk-and-the-space-race
# no iframe found: jfk-assassination-tapes
# structure unknown: jfk-consults-excomm-about-concluding-missile-crisis
# structure unknown: jfk-consults-excomm-about-growing-missile-crisis
# no iframe found: jfk-lbj-the-midterm-elections-of-1962-and-1966
# structure unknown: jfk-nuclear-launch-procedures
# structure unknown: jfks-memoir-dictation-on-the-assassination-of-diem
# no iframe found: john-f-kennedy-on-politics-and-public-service
# structure unknown: johnson-mills-s-korea-australia
# structure unknown: kennedy-and-eisenhower
# structure unknown: kennedy-meeting-with-white-birmingham-leaders
# structure unknown: lbj-and-hubert-humphrey-on-the-democratic-party
# structure unknown: lbj-and-jacqueline-kennedy
# structure inconsistent: lbj-and-richard-russell-on-vietnam
# structure unknown: lbj-and-the-logic-of-escalation
# no iframe found: lbj-and-the-response-to-hurricane-betsy
# structure unknown: lbj-charles-halleck-and-the-passage-of-the-civil-rights-bill
# no iframe found: lbj-governor-wallace-and-buford-ellington-in-selma-alabama
# no iframe found: lbj-nixon-and-john-s-mccain-sr-jr-and-iii
# structure unknown: lbj-on-affirmative-action
# structure unknown: lbj-on-ted-sorensen
# structure unknown: lbj-reviews-us-foreign-policy
# no iframe found: lbjs-nomination-of-abe-fortas
# structure unknown: lessons-for-2012
# no iframe found: let-democrats-squeal
# structure unknown: lyndon-johnson-and-arthur-goldberg-on-immigration
# structure unknown: lyndon-johnson-and-nicholas-katzenbach-on-the-immigration-bill
# no iframe found: marshall-plan
# structure unknown: medicare-and-lbjs-three-prong-approach
# structure unknown: meeting-on-brazilian-elections
# no iframe found: mississippi-burning
# structure unknown: nixon-and-billy-graham-on-vietnam
# structure unknown: nixon-and-donald-rumsfeld-discuss-comments-by-agnew
# no iframe found: nixon-and-the-amchitka-nuclear-test-november-1971
# structure unknown: nixon-kissinger-and-the-decent-interval
# structure unknown: pierre-salinger-and-oliver-hallet
# structure unknown: preparing-a-response
# structure unknown: president-kennedy-on-harvard-economists
# structure unknown: president-kennedy-on-the-foreign-service
# structure unknown: president-kennedys-job-offer-to-willard-wirtz
# structure unknown: presidents-and-tax-policy
# structure unknown: reporting-vietnam
# structure unknown: richard-nixon-reflects-on-youth-today
# structure unknown: robert-kennedy-on-a-possible-coup-in-south-vietnam
# no iframe found: see-if-his-phone-bugged-or-something
# no iframe found: selma
# no iframe found: senator-edward-kennedy-and-the-white-house-tapes
# no iframe found: smoking-gun
# structure unknown: status-report-on-vietnam
# no iframe found: taping-system-logistics
# structure unknown: testing-sargent-shriver-vietnam-and-assassinations
# structure unknown: the-cia-on-the-sino-soviet-dispute
# no iframe found: the-future-presidents-club
# structure unknown: the-kennedy-withdrawal
# no iframe found: the-murder-of-civil-rights-activist-jonathan-daniels-august-20-1965
# structure unknown: the-ole-miss-crisis
# structure unknown: the-tripartite-pact
# structure unknown: these-people-are-taking-our-jobs
# structure inconsistent: theyd-impeach-a-president-lbj-and-richard-russell-on-vietnam
# structure unknown: this-is-treason
# structure unknown: thomas-eagleton
# no iframe found: thurgood-marshall-lbj-johnson-tapes
# no iframe found: too-many-nice-guys
# no iframe found: troop-levels
# structure unknown: vietnam-getting-in-or-getting-out
# structure unknown: vietnam-more-war-or-more-appeasement
# no iframe found: watergate-above-the-law
# structure unknown: wheeler-report
# no iframe found: why-didnt-nixon-burn-the-tapes
# no iframe found: you-cant-screw-around-irs
# no iframe found: you-could-get-million-dollars
# no iframe found: you-need-team

# %%
# Write table to CSV.

import csv
import sys

fieldnames = (
    'url',
    'page_title',
    'title',
    'date_of_recording',
    'conversation_number',
    'participant1',
    'participant2',
    'participant3',
    'participant4',
    'participant5',
    'participant6',
)

def write_csv(exhibit_list, fd, fieldnames=fieldnames):
    writer = csv.DictWriter(fd, fieldnames=fieldnames)
    writer.writeheader()
    for exhibit in exhibit_list:
        writer.writerow(exhibit)

write_csv(exhibit_list, open('exhibits.csv', 'w'))
log.close()

# %%
# Preview the CSV.

import pandas as pd

pd.read_csv('exhibits.csv')
# Out:
#                                                    url  \
# 0    millercenter.org/presidentialclassroom/exhibit...
# 1    millercenter.org/presidentialclassroom/exhibit...
# 2    millercenter.org/presidentialclassroom/exhibit...
# 3    millercenter.org/presidentialclassroom/exhibit...
# 4    millercenter.org/presidentialclassroom/exhibit...
# 5    millercenter.org/presidentialclassroom/exhibit...
# 6    millercenter.org/presidentialclassroom/exhibit...
# 7    millercenter.org/presidentialclassroom/exhibit...
# 8    millercenter.org/presidentialclassroom/exhibit...
# 9    millercenter.org/presidentialclassroom/exhibit...
# 10   millercenter.org/presidentialclassroom/exhibit...
# 11   millercenter.org/presidentialclassroom/exhibit...
# 12   millercenter.org/presidentialclassroom/exhibit...
# 13   millercenter.org/presidentialclassroom/exhibit...
# 14   millercenter.org/presidentialclassroom/exhibit...
# 15   millercenter.org/presidentialclassroom/exhibit...
# 16   millercenter.org/presidentialclassroom/exhibit...
# 17   millercenter.org/presidentialclassroom/exhibit...
# 18   millercenter.org/presidentialclassroom/exhibit...
# 19   millercenter.org/presidentialclassroom/exhibit...
# 20   millercenter.org/presidentialclassroom/exhibit...
# 21   millercenter.org/presidentialclassroom/exhibit...
# 22   millercenter.org/presidentialclassroom/exhibit...
# 23   millercenter.org/presidentialclassroom/exhibit...
# 24   millercenter.org/presidentialclassroom/exhibit...
# 25   millercenter.org/presidentialclassroom/exhibit...
# 26   millercenter.org/presidentialclassroom/exhibit...
# 27   millercenter.org/presidentialclassroom/exhibit...
# 28   millercenter.org/presidentialclassroom/exhibit...
# 29   millercenter.org/presidentialclassroom/exhibit...
# ..                                                 ...
# 82   millercenter.org/presidentialclassroom/exhibit...
# 83   millercenter.org/presidentialclassroom/exhibit...
# 84   millercenter.org/presidentialclassroom/exhibit...
# 85   millercenter.org/presidentialclassroom/exhibit...
# 86   millercenter.org/presidentialclassroom/exhibit...
# 87   millercenter.org/presidentialclassroom/exhibit...
# 88   millercenter.org/presidentialclassroom/exhibit...
# 89   millercenter.org/presidentialclassroom/exhibit...
# 90   millercenter.org/presidentialclassroom/exhibit...
# 91   millercenter.org/presidentialclassroom/exhibit...
# 92   millercenter.org/presidentialclassroom/exhibit...
# 93   millercenter.org/presidentialclassroom/exhibit...
# 94   millercenter.org/presidentialclassroom/exhibit...
# 95   millercenter.org/presidentialclassroom/exhibit...
# 96   millercenter.org/presidentialclassroom/exhibit...
# 97   millercenter.org/presidentialclassroom/exhibit...
# 98   millercenter.org/presidentialclassroom/exhibit...
# 99   millercenter.org/presidentialclassroom/exhibit...
# 100  millercenter.org/presidentialclassroom/exhibit...
# 101  millercenter.org/presidentialclassroom/exhibit...
# 102  millercenter.org/presidentialclassroom/exhibit...
# 103  millercenter.org/presidentialclassroom/exhibit...
# 104  millercenter.org/presidentialclassroom/exhibit...
# 105  millercenter.org/presidentialclassroom/exhibit...
# 106  millercenter.org/presidentialclassroom/exhibit...
# 107  millercenter.org/presidentialclassroom/exhibit...
# 108  millercenter.org/presidentialclassroom/exhibit...
# 109  millercenter.org/presidentialclassroom/exhibit...
# 110  millercenter.org/presidentialclassroom/exhibit...
# 111  millercenter.org/presidentialclassroom/exhibit...
#
#                                             page_title  \
# 0    October 5, 1963: 1,000 Troop Withdrawal from S...
# 1    October 2, 1963: 1,000 Troop Withdrawal from S...
# 2                    A 3 A.M. Phone Call—Miller Center
# 3       A Bipartisan Transportation Bill—Miller Center
# 4                  A Global Enemies List—Miller Center
# 5    African Americans and the U.S. Military—Miller...
# 6    All the Incentives are Toward Less Medical Car...
# 7    An Optimistic Budget and Solid Poverty Program...
# 8                “As Far As We Can Tell”—Miller Center
# 9                      Assessing the War—Miller Center
# 10   Bob Haldeman’s Audio Diary Entry on Nixon’s Pl...
# 11                   Bombs in Birmingham—Miller Center
# 12                       “Cap the Knife”—Miller Center
# 13   Charles Bohlen on the Sino-Soviet Dispute—Mill...
# 14       Colson and Nixon on Howard Hunt—Miller Center
# 15   Congratulations . . . and a Request—Miller Center
# 16            Congressional Coordination—Miller Center
# 17            Cut Off His [Thieu’s] Head—Miller Center
# 18   Gen. Earle Wheeler on David Halberstam and the...
# 19                    Explaining Vietnam—Miller Center
# 20             Finding Fannie Lou Chaney—Miller Center
# 21                    Fly Me To the Moon—Miller Center
# 22                           “Good Lord”—Miller Center
# 23   Ground Troops and the Tonkin Gulf Resolution—M...
# 24             Hiring People to Hurt Him—Miller Center
# 25             “I Think That’s Hopeless”—Miller Center
# 26   “I Thought We Were Going to Have CCC Camps”—Mi...
# 27    Janet Leigh’s FBI Background Check—Miller Center
# 28              JFK and Nuclear Strategy—Miller Center
# 29   JFK Orders “One of Those Blue Pills”—Miller Ce...
# ..                                                 ...
# 82     Oliver Hallet and Pierre Salinger—Miller Center
# 83   Poverty, Religion, and Military Base Closures—...
# 84   President Johnson and Martin Luther King Jr. o...
# 85   President Johnson and Mrs. Nathan Schwerner—Mi...
# 86   President Johnson Compares the War on Poverty ...
# 87   President Nixon and Bob Haldeman on Fred Malek...
# 88   President Richard M. Nixon and Gerald Ford on ...
# 89   Sen. Ribicoff Outlines Problems in the War on ...
# 90                 Signing the Farm Bill—Miller Center
# 91                     “Some Fool Thing”—Miller Center
# 92            Swimming With Billy Graham—Miller Center
# 93                  The Best in the Army—Miller Center
# 94            The Context for Withdrawal—Miller Center
# 95              The Contingencies of War—Miller Center
# 96          The Economic Opportunity Act—Miller Center
# 97       “The Greatest Man In The World”—Miller Center
# 98     The Kennedy Withdrawal (Combined)—Miller Center
# 99                The Pandas Are Coming!—Miller Center
# 100             The Politics of Medicare—Miller Center
# 101  The War on Poverty and Racial Tension in the U...
# 102                   The Wheeler Report—Miller Center
# 103  “There Ain’t No Daylight in Vietnam”—Miller Ce...
# 104            “These Covert Operations”—Miller Center
# 105  “They Just Can’t Get the Americans to Do It”—M...
# 106               This Will be Forgotten—Miller Center
# 107               Tricia Nixon’s Wedding—Miller Center
# 108   Vietnam and the Ghost of Ben Milam—Miller Center
# 109      Watergate: They Have to be Paid—Miller Center
# 110                              We Won!—Miller Center
# 111         “You’re in a Pretty Bad Fix”—Miller Center
#
#                                                  title  \
# 0    October 5, 1963: 1,000 Troop Withdrawal from S...
# 1    October 2, 1963: 1,000 Troop Withdrawal from S...
# 2                                  A 3 A.M. Phone Call
# 3                     A Bipartisan Transportation Bill
# 4                                A Global Enemies List
# 5              African Americans and the U.S. Military
# 6      All the Incentives are Toward Less Medical Care
# 7      An Optimistic Budget and Solid Poverty Programs
# 8                              “As Far As We Can Tell”
# 9                                    Assessing the War
# 10   Bob Haldeman’s Audio Diary Entry on Nixon’s Pl...
# 11                                 Bombs in Birmingham
# 12                                     “Cap the Knife”
# 13           Charles Bohlen on the Sino-Soviet Dispute
# 14                     Colson and Nixon on Howard Hunt
# 15                 Congratulations . . . and a Request
# 16                          Congressional Coordination
# 17                          Cut Off His [Thieu’s] Head
# 18   Gen. Earle Wheeler on David Halberstam and the...
# 19                                  Explaining Vietnam
# 20                           Finding Fannie Lou Chaney
# 21                                  Fly Me To the Moon
# 22                                         “Good Lord”
# 23        Ground Troops and the Tonkin Gulf Resolution
# 24                           Hiring People to Hurt Him
# 25                           “I Think That’s Hopeless”
# 26         “I Thought We Were Going to Have CCC Camps”
# 27                  Janet Leigh’s FBI Background Check
# 28                            JFK and Nuclear Strategy
# 29                JFK Orders “One of Those Blue Pills”
# ..                                                 ...
# 82                   Oliver Hallet and Pierre Salinger
# 83       Poverty, Religion, and Military Base Closures
# 84   President Johnson and Martin Luther King Jr. o...
# 85         President Johnson and Mrs. Nathan Schwerner
# 86   President Johnson Compares the War on Poverty ...
# 87      President Nixon and Bob Haldeman on Fred Malek
# 88   President Richard M. Nixon and Gerald Ford on ...
# 89   Sen. Ribicoff Outlines Problems in the War on ...
# 90                               Signing the Farm Bill
# 91                                   “Some Fool Thing”
# 92                          Swimming With Billy Graham
# 93                                The Best in the Army
# 94                          The Context for Withdrawal
# 95                            The Contingencies of War
# 96                        The Economic Opportunity Act
# 97                     “The Greatest Man In The World”
# 98                   The Kennedy Withdrawal (Combined)
# 99                              The Pandas Are Coming!
# 100                           The Politics of Medicare
# 101  The War on Poverty and Racial Tension in the U...
# 102                                 The Wheeler Report
# 103               “There Ain’t No Daylight in Vietnam”
# 104                          “These Covert Operations”
# 105       “They Just Can’t Get the Americans to Do It”
# 106                             This Will be Forgotten
# 107                             Tricia Nixon’s Wedding
# 108                 Vietnam and the Ghost of Ben Milam
# 109                    Watergate: They Have to be Paid
# 110                                            We Won!
# 111                       “You’re in a Pretty Bad Fix”
#
#                date_of_recording      conversation_number  \
# 0                   Oct 05, 1963  114/A50.1 and 114/A50.2
# 1                   Oct 02, 1963                  114/A49
# 2                   Mar 28, 1964           WH6403.17-2681
# 3                   Oct 05, 1966          WH6610-03-10925
# 4                   Oct 27, 1971                  604-009
# 5                   Sep 27, 1940                 48-61(1)
# 6                   Feb 17, 1971                  450-023
# 7                   Dec 23, 1963              K6312-15-01
# 8                   Aug 04, 1964      NMCC Tapes, VN01.10
# 9                   Nov 02, 1965           WH6511.01-9103
# 10                  Dec 21, 1970      H.R. Haldeman Diary
# 11                  Sep 19, 1963          111.7 and 112.1
# 12                  Jun 08, 1971                   e514.7
# 13                  Sep 29, 1962                  Tape 25
# 14                  Jul 01, 1972                  746-003
# 15                  Jan 19, 1965           WH6501.04-0005
# 16                  Jul 01, 1964           WH6407-01-4106
# 17                  Jan 20, 1973                  036-021
# 18                  Feb 02, 1963            71.2 and 71.2
# 19                  Mar 21, 1964           WH6403.13-2584
# 20                  Jun 23, 1964           WH6406.16-3887
# 21                  Nov 21, 1962                 Tape 63A
# 22                  Aug 06, 1964           WH6408.09-4777
# 23                  Jul 02, 1965           WH6507.01-8302
# 24                  Feb 03, 1967          WH6702-01-11410
# 25                  Dec 02, 1963              K6312-02-09
# 26                  Aug 07, 1964           WH6408.12-4817
# 27                  Mar 12, 1964           WH6403.09-2491
# 28                  Dec 05, 1962           Tapes 65.2, 66
# 29   Mar 01, 1963 - Mar 31, 1963           Dictabelt 9.B7
# ..                           ...                      ...
# 82                  Nov 22, 1963                  0-969-1
# 83                  May 11, 1964     WH6405.04-3393, 3394
# 84                  Aug 20, 1965           WH6508.07-8578
# 85                  Jun 23, 1964          WH6406.16 #3882
# 86                  Nov 05, 1964           WH6411.07-6216
# 87                  Jul 03, 1971                  536-016
# 88                  May 05, 1971                  492-003
# 89                  Aug 19, 1965           WH6508.07-8574
# 90                  Apr 09, 1964           WH6404.06-2957
# 91                  Oct 08, 1940               48-61:8(2)
# 92                  May 13, 1964     WH6405.05-3431, 3432
# 93                  Apr 02, 1964           WH6404.02-2833
# 94                  May 07, 1963                       85
# 95                  Oct 25, 1940                  48-61:4
# 96                  May 14, 1964           WH6405.07-3453
# 97                  May 02, 1964           WH6405.01-3323
# 98                  Oct 02, 1963                  114/A49
# 99                  Mar 13, 1972          021-056 Track 5
# 100                 May 18, 1964           WH6405.08-3472
# 101                 Jul 30, 1964           WH6407.13-4336
# 102                 Feb 02, 1963    1963-02-02_71.1, 71.2
# 103                 Mar 06, 1965         WH6503.03, #7207
# 104                 Aug 03, 1964           WH6408.03-4633
# 105                 Aug 18, 1965           WH6508.05-8558
# 106                 Jun 20, 1972                  342-027
# 107                 Jun 12, 1971    rmn_e518a_New_Quakers
# 108                 May 27, 1964     WH6405.10-3520, 3521
# 109                 Aug 01, 1972                  758-011
# 110                 Nov 03, 1964           WH6411.01-6121
# 111                 Oct 19, 1962                Tape 31.2
#
#                                           participant1  \
# 0                                         John Kennedy
# 1                                         John Kennedy
# 2                                       Lyndon Johnson
# 3                                       Lyndon Johnson
# 4                                        Richard Nixon
# 5                                   Franklin Roosevelt
# 6                                        Richard Nixon
# 7                                       Lyndon Johnson
# 8                             Admiral U.S. Grant Sharp
# 9                                       Lyndon Johnson
# 10                                        Bob Haldeman
# 11                                        John Kennedy
# 12                                       Richard Nixon
# 13                                        John Kennedy
# 14                                       Richard Nixon
# 15                                      Lyndon Johnson
# 16                                      Lyndon Johnson
# 17                                       Richard Nixon
# 18                                        John Kennedy
# 19                                      Lyndon Johnson
# 20                                           Lee White
# 21                                        John Kennedy
# 22                                      Lyndon Johnson
# 23                                      Lyndon Johnson
# 24                                      Lyndon Johnson
# 25                                      Lyndon Johnson
# 26                                      Lyndon Johnson
# 27                                      Lyndon Johnson
# 28                                        John Kennedy
# 29                                        John Kennedy
# ..                                                 ...
# 82                                     Pierre Salinger
# 83                                      Lyndon Johnson
# 84                                      Lyndon Johnson
# 85                                      Lyndon Johnson
# 86                                      Lyndon Johnson
# 87                                       Richard Nixon
# 88                                       Richard Nixon
# 89                                      Lyndon Johnson
# 90                                      Lyndon Johnson
# 91                                  Franklin Roosevelt
# 92                                      Lyndon Johnson
# 93                                      Lyndon Johnson
# 94                                        John Kennedy
# 95                                  Franklin Roosevelt
# 96                                      Lyndon Johnson
# 97                                      Lyndon Johnson
# 98   John Kennedy and Senior Civilian and Military ...
# 99                                       Richard Nixon
# 100                                     Lyndon Johnson
# 101                                     Lyndon Johnson
# 102                                       John Kennedy
# 103                                     Lyndon Johnson
# 104                                     Lyndon Johnson
# 105                                     Lyndon Johnson
# 106                                      Richard Nixon
# 107                                      Richard Nixon
# 108                                     Lyndon Johnson
# 109                                      Richard Nixon
# 110                                     Lyndon Johnson
# 111                                       John Kennedy
#
#                 participant2        participant3    participant4  \
# 0            Robert McNamara                 NaN             NaN
# 1            Robert McNamara      Maxwell Taylor  McGeorge Bundy
# 2               George Reedy                 NaN             NaN
# 3            Robert Anderson                 NaN             NaN
# 4               Bob Haldeman      Charles Colson             NaN
# 5         A. Philip Randolph        Walter White             NaN
# 6            John Ehrlichman                 NaN             NaN
# 7              Walter Heller                 NaN             NaN
# 8    General David Burchinal                 NaN             NaN
# 9            Robert McNamara                 NaN             NaN
# 10                       NaN                 NaN             NaN
# 11      Civil Rights Leaders                 NaN             NaN
# 12         Caspar Weinberger                 NaN             NaN
# 13            Charles Bohlen  Llewellyn Thompson             NaN
# 14            Charles Colson                 NaN             NaN
# 15               Gerald Ford                 NaN             NaN
# 16           George Smathers                 NaN             NaN
# 17           Henry Kissinger                 NaN             NaN
# 18             Earle Wheeler                 NaN             NaN
# 19           Robert McNamara                 NaN             NaN
# 20     White House Operators                 NaN             NaN
# 21                James Webb      Robert Seamans     Hugh Dryden
# 22                James Rowe                 NaN             NaN
# 23           Robert McNamara                 NaN             NaN
# 24                 John Macy                 NaN             NaN
# 25         William Fulbright                 NaN             NaN
# 26               Bill Moyers                 NaN             NaN
# 27           J. Edgar Hoover                 NaN             NaN
# 28            Maxwell Taylor                 NaN             NaN
# 29            George Burkley                 NaN             NaN
# ..                       ...                 ...             ...
# 82             Oliver Hallet                 NaN             NaN
# 83            John McCormack         Bill Moyers             NaN
# 84    Martin Luther King Jr.                 NaN             NaN
# 85     Mrs. Nathan Schwerner                 NaN             NaN
# 86           Joseph S. Clark                 NaN             NaN
# 87              Bob Haldeman                 NaN             NaN
# 88               Gerald Ford       John Mitchell             NaN
# 89          Abraham Ribicoff                 NaN             NaN
# 90             Larry O'Brien                 NaN             NaN
# 91                       NaN                 NaN             NaN
# 92            Frank Thompson                 NaN             NaN
# 93           Robert McNamara                 NaN             NaN
# 94           Robert McNamara                 NaN             NaN
# 95                       NaN                 NaN             NaN
# 96              Phil Landrum                 NaN             NaN
# 97           Hubert Humphrey                 NaN             NaN
# 98                       NaN                 NaN             NaN
# 99                 Pat Nixon                 NaN             NaN
# 100            Larry O'Brien                 NaN             NaN
# 101    Francis "Frank" Smith                 NaN             NaN
# 102          Senior Civilian   Military Advisers             NaN
# 103          Richard Russell                 NaN             NaN
# 104          Robert McNamara                 NaN             NaN
# 105         Spessard Holland                 NaN             NaN
# 106           Charles Colson                 NaN             NaN
# 107            H.R. Haldeman                 NaN             NaN
# 108          Richard Russell                 NaN             NaN
# 109             Bob Haldeman                 NaN             NaN
# 110          Hubert Humphrey                 NaN             NaN
# 111             Curtis LeMay                 NaN             NaN
#
#        participant5  participant6
# 0               NaN           NaN
# 1            et al.           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# 5               NaN           NaN
# 6               NaN           NaN
# 7               NaN           NaN
# 8               NaN           NaN
# 9               NaN           NaN
# 10              NaN           NaN
# 11              NaN           NaN
# 12              NaN           NaN
# 13              NaN           NaN
# 14              NaN           NaN
# 15              NaN           NaN
# 16              NaN           NaN
# 17              NaN           NaN
# 18              NaN           NaN
# 19              NaN           NaN
# 20              NaN           NaN
# 21   Jerome Wiesner           NaN
# 22              NaN           NaN
# 23              NaN           NaN
# 24              NaN           NaN
# 25              NaN           NaN
# 26              NaN           NaN
# 27              NaN           NaN
# 28              NaN           NaN
# 29              NaN           NaN
# ..              ...           ...
# 82              NaN           NaN
# 83              NaN           NaN
# 84              NaN           NaN
# 85              NaN           NaN
# 86              NaN           NaN
# 87              NaN           NaN
# 88              NaN           NaN
# 89              NaN           NaN
# 90              NaN           NaN
# 91              NaN           NaN
# 92              NaN           NaN
# 93              NaN           NaN
# 94              NaN           NaN
# 95              NaN           NaN
# 96              NaN           NaN
# 97              NaN           NaN
# 98              NaN           NaN
# 99              NaN           NaN
# 100             NaN           NaN
# 101             NaN           NaN
# 102             NaN           NaN
# 103             NaN           NaN
# 104             NaN           NaN
# 105             NaN           NaN
# 106             NaN           NaN
# 107             NaN           NaN
# 108             NaN           NaN
# 109             NaN           NaN
# 110             NaN           NaN
# 111             NaN           NaN
#
# [112 rows x 11 columns]
